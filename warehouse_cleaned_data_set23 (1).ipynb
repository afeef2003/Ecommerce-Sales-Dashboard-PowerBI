# %% [markdown]
# # Importing all the necsessary libaries for peforming operations

# %%
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Inserting the data

# %%
sales_data=pd.read_csv("/content/Cloud Warehouse Compersion Chart.csv")

# %%
sales_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   index       50 non-null     int64
#  1   Shiprocket  21 non-null     object
#  2   Unnamed: 1  41 non-null     object
#  3   INCREFF     28 non-null     object
# dtypes: int64(1), object(3)
# memory usage: 1.7+ KB

# %%
sales_data.head(49)
# Out:
#     index                                         Shiprocket  \
# 0       0                                              Heads
# 1       1                      Inbound (Fresh Stock and RTO)
# 2       2                                           Outbound
# 3       3                                    Storage Fee/Cft
# 4       4                   Customer Return with Detailed QC
# 5       5  (A) SCOPE OF WORK and STANDARD OPERATING PROCE...
# 6       6                                             Inward
# 7       7                                                NaN
# 8       8                                                NaN
# 9       9                                                NaN
# 10     10                                                NaN
# 11     11                                                NaN
# 12     12                                            Outward
# 13     13                                                NaN
# ...

# %%
sales_data.describe()
# Out:
#           index
# count  50.00000
# mean   24.50000
# std    14.57738
# min     0.00000
# 25%    12.25000
# 50%    24.50000
# 75%    36.75000
# max    49.00000

# %%
sales_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   index       50 non-null     int64
#  1   Shiprocket  21 non-null     object
#  2   Unnamed: 1  41 non-null     object
#  3   INCREFF     28 non-null     object
# dtypes: int64(1), object(3)
# memory usage: 1.7+ KB

# %%
sales_data.shape
# Out:
# (50, 4)

# %%
sales_data.columns
# Out:
# Index(['index', 'Shiprocket', 'Unnamed: 1', 'INCREFF'], dtype='object')

# %%
sales_data.isnull()
# Out:
#     index  Shiprocket  Unnamed: 1  INCREFF
# 0   False       False       False    False
# 1   False       False       False    False
# 2   False       False       False    False
# 3   False       False       False    False
# 4   False       False       False    False
# 5   False       False        True     True
# 6   False       False       False    False
# 7   False        True       False    False
# 8   False        True       False    False
# 9   False        True       False    False
# 10  False        True       False    False
# 11  False        True        True     True
# 12  False       False       False    False
# 13  False        True       False    False
# 14  False        True       False    False
# 15  False        True       False    False
# 16  False        True       False    False
# 17  False        True       False    False
# 18  False        True        True     True
# 19  False       False       False    False
# 20  False        True        True     True
# ...

# %%
sales_data.isnull().sum()
# Out:
# index          0
# Shiprocket    29
# Unnamed: 1     9
# INCREFF       22
# dtype: int64

# %%
sales_data_dropped_rows = sales_data.dropna()

# %%
sales_data.shape
# Out:
# (50, 4)

# %%
sales_data_dropped_rows.shape
# Out:
# (15, 4)

# %%
# missing values drop hone ke baad data itna hi bacha

# %%
print("\nDataFrame after dropping rows with nulls:\n", sales_data_dropped_rows)
# Out:
# DataFrame after dropping rows with nulls:
#      index                        Shiprocket  \
# 0       0                             Heads
# 1       1     Inbound (Fresh Stock and RTO)
# 2       2                          Outbound
# 3       3                   Storage Fee/Cft
# 4       4  Customer Return with Detailed QC
# 6       6                            Inward
# 12     12                           Outward
# 19     19                           Returns
# 21     21              Inventory management
# 37     37               Performance Measure
# 38     38                 Monthly Fill Rate
# 43     43               Customer Complaints
# 45     45                 Allowed Shrinkage
# 47     47                           Penalty
# 49     49                            Others
#
#                                            Unnamed: 1  \
# 0                                    Price (Per Unit)
# 1                                               ₹4.00
# ...

# %%
# here i used forward filling for fill the nan values
sales_data_ffill = sales_data.fillna(method='ffill')
print("\nDataFrame after forward filling:\n", sales_data_ffill)
# Out:
# DataFrame after forward filling:
#      index                                         Shiprocket  \
# 0       0                                              Heads
# 1       1                      Inbound (Fresh Stock and RTO)
# 2       2                                           Outbound
# 3       3                                    Storage Fee/Cft
# 4       4                   Customer Return with Detailed QC
# 5       5  (A) SCOPE OF WORK and STANDARD OPERATING PROCE...
# 6       6                                             Inward
# 7       7                                             Inward
# 8       8                                             Inward
# 9       9                                             Inward
# 10     10                                             Inward
# 11     11                                             Inward
# 12     12                                            Outward
# 13     13                                            Outward
# ...

# %% [markdown]
# # now you can perform the operations as per your needs
