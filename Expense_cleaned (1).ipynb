# %% [markdown]
# # importing libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # inserting the dataset

# %%
sales_data = pd.read_csv('/content/Expense IIGF.csv')

# %% [markdown]
# # seeing a data whether it contains missing values or any other ourtlier

# %%
sales_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17 entries, 0 to 16
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   index           17 non-null     int64
#  1   Recived Amount  6 non-null      object
#  2   Unnamed: 1      6 non-null      object
#  3   Expance         15 non-null     object
#  4   Unnamed: 3      17 non-null     object
# dtypes: int64(1), object(4)
# memory usage: 808.0+ bytes

# %%
sales_data.head(17)
# Out:
#     index Recived Amount Unnamed: 1  \
# 0       0     Particular     Amount
# 1       1       06-19-22       1000
# 2       2       06-20-22       1500
# 3       3       06-22-22        500
# 4       4       06-23-22       2000
# 5       5            NaN        NaN
# 6       6            NaN        NaN
# 7       7            NaN        NaN
# 8       8            NaN        NaN
# 9       9            NaN        NaN
# 10     10            NaN        NaN
# 11     11            NaN        NaN
# 12     12            NaN        NaN
# 13     13            NaN        NaN
# 14     14            NaN        NaN
# 15     15            NaN        NaN
# 16     16          Total       5000
#
#                                               Expance Unnamed: 3
# 0                                          Particular     Amount
# 1                                           Large Bag        380
# 2   Stationary(Soft Pin, Paper pin for Dupatta, Fe...        170
# ...

# %%
# Check if there are any missing values in the DataFrame
any_missing = sales_data.isnull().values.any()
print("\nAny missing values in DataFrame?:", any_missing)
# Out:
# Any missing values in DataFrame?: True

# %%
import missingno as msno

# Visualize missing values using missingno
msno.matrix(sales_data)
plt.show()

# %% [markdown]
# # the provided data contains some missing values in it, we have to perform the operation on it
# # the operation are as follow:
# # i am using the forward filling because data set is already very small therefore we have add some values without infulencing the actual values it is effecient for this type of condition

# %%
sales_data_ffill = sales_data.fillna(method='ffill')
print("\nDataFrame after forward filling:\n", sales_data_ffill)
# Out:
# DataFrame after forward filling:
#      index Recived Amount Unnamed: 1  \
# 0       0     Particular     Amount
# 1       1       06-19-22       1000
# 2       2       06-20-22       1500
# 3       3       06-22-22        500
# 4       4       06-23-22       2000
# 5       5       06-23-22       2000
# 6       6       06-23-22       2000
# 7       7       06-23-22       2000
# 8       8       06-23-22       2000
# 9       9       06-23-22       2000
# 10     10       06-23-22       2000
# 11     11       06-23-22       2000
# 12     12       06-23-22       2000
# 13     13       06-23-22       2000
# 14     14       06-23-22       2000
# 15     15       06-23-22       2000
# 16     16          Total       5000
#
#                                               Expance Unnamed: 3
# 0                                          Particular     Amount
# 1                                           Large Bag        380
# 2   Stationary(Soft Pin, Paper pin for Dupatta, Fe...        170
# ...

# %%
print(sales_data_ffill.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17 entries, 0 to 16
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   index           17 non-null     int64
#  1   Recived Amount  17 non-null     object
#  2   Unnamed: 1      17 non-null     object
#  3   Expance         17 non-null     object
#  4   Unnamed: 3      17 non-null     object
# dtypes: int64(1), object(4)
# memory usage: 808.0+ bytes
# None

# %%
sales_data_ffill.head(17)
# Out:
#     index Recived Amount Unnamed: 1  \
# 0       0     Particular     Amount
# 1       1       06-19-22       1000
# 2       2       06-20-22       1500
# 3       3       06-22-22        500
# 4       4       06-23-22       2000
# 5       5       06-23-22       2000
# 6       6       06-23-22       2000
# 7       7       06-23-22       2000
# 8       8       06-23-22       2000
# 9       9       06-23-22       2000
# 10     10       06-23-22       2000
# 11     11       06-23-22       2000
# 12     12       06-23-22       2000
# 13     13       06-23-22       2000
# 14     14       06-23-22       2000
# 15     15       06-23-22       2000
# 16     16          Total       5000
#
#                                               Expance Unnamed: 3
# 0                                          Particular     Amount
# 1                                           Large Bag        380
# 2   Stationary(Soft Pin, Paper pin for Dupatta, Fe...        170
# ...

# %% [markdown]
# # now the data is ready for performing the operation as per you needs
